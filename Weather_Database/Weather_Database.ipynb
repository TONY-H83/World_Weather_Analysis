# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 780

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                          "Country": city_country,
                            "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | tucurui
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | alofi
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | richards bay
# Processing Record 12 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 1 | cayenne
# Processing Record 14 of Set 1 | gizo
# Processing Record 15 of Set 1 | lavrentiya
# Processing Record 16 of Set 1 | manavgat
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | onega
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | tema
# Processing Record 24 of Set 1 | kovur
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | lasa
# Processing Record 27 of Set 1 | frederikshavn
# Processing Record 28 of Set 1 | east wenatchee bench
# Processing Record 29 of Set 1 | kiruna
# Processing Record 30 of Set 1 | sinnamary
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | costa rica
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | gora
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | bongandanga
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | ranong
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | pangnirtung
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | balsas
# Processing Record 47 of Set 1 | suntar
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 1 | dunedin
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | calatrava
# Processing Record 3 of Set 2 | brownsville
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | wernberg
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | bayamo
# Processing Record 8 of Set 2 | asau
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | kayes
# Processing Record 12 of Set 2 | sikonge
# Processing Record 13 of Set 2 | acajutla
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | obidos
# Processing Record 18 of Set 2 | hamina
# Processing Record 19 of Set 2 | nelson bay
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | grindavik
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | vestmanna
# Processing Record 25 of Set 2 | jinchang
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | kavant
# City not found. Skipping...
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | katsuura
# Processing Record 33 of Set 2 | keti bandar
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | aden
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | denpasar
# Processing Record 38 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | roebourne
# Processing Record 42 of Set 2 | jilib
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | aksarka
# Processing Record 45 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | changtu
# Processing Record 49 of Set 2 | lyndon
# Processing Record 50 of Set 2 | bonfim
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | opuwo
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | kenai
# Processing Record 8 of Set 3 | baltasi
# Processing Record 9 of Set 3 | salalah
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | isla vista
# Processing Record 15 of Set 3 | kununurra
# Processing Record 16 of Set 3 | yumen
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | yerbogachen
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | korla
# Processing Record 21 of Set 3 | waitati
# Processing Record 22 of Set 3 | derzhavinsk
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | pocone
# Processing Record 25 of Set 3 | charleston
# Processing Record 26 of Set 3 | guayaramerin
# Processing Record 27 of Set 3 | vila velha
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | tomatlan
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | beloha
# Processing Record 32 of Set 3 | priargunsk
# Processing Record 33 of Set 3 | dongning
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | la ronge
# Processing Record 36 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 3 | doka
# Processing Record 38 of Set 3 | oktyabrskiy
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | aswan
# Processing Record 42 of Set 3 | arlit
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | le port
# Processing Record 46 of Set 3 | colquiri
# Processing Record 47 of Set 3 | westerly
# Processing Record 48 of Set 3 | verkhniy rohachyk
# Processing Record 49 of Set 3 | sidi ali
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | atar
# Processing Record 3 of Set 4 | aranos
# Processing Record 4 of Set 4 | morehead
# Processing Record 5 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 4 | dori
# Processing Record 7 of Set 4 | belmonte
# Processing Record 8 of Set 4 | san andres
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | karangampel
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | preobrazheniye
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | erenhot
# Processing Record 15 of Set 4 | saint-joseph
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | paamiut
# Processing Record 18 of Set 4 | camacha
# Processing Record 19 of Set 4 | albury
# Processing Record 20 of Set 4 | hualmay
# Processing Record 21 of Set 4 | nova olimpia
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | aller
# Processing Record 24 of Set 4 | itarema
# Processing Record 25 of Set 4 | pokhara
# Processing Record 26 of Set 4 | scarborough
# Processing Record 27 of Set 4 | nanakuli
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | khor
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | oksfjord
# Processing Record 33 of Set 4 | katobu
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | bollnas
# Processing Record 36 of Set 4 | waddan
# Processing Record 37 of Set 4 | pine bluff
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | puerto ayora
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | cedar city
# Processing Record 42 of Set 4 | matara
# Processing Record 43 of Set 4 | sistranda
# Processing Record 44 of Set 4 | whitianga
# Processing Record 45 of Set 4 | havre-saint-pierre
# Processing Record 46 of Set 4 | mahebourg
# Processing Record 47 of Set 4 | swan hill
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | kholm
# Processing Record 2 of Set 5 | tilichiki
# Processing Record 3 of Set 5 | dikson
# Processing Record 4 of Set 5 | huarmey
# Processing Record 5 of Set 5 | jacareacanga
# Processing Record 6 of Set 5 | nikolskoye
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | jujutla
# Processing Record 9 of Set 5 | namatanai
# Processing Record 10 of Set 5 | leme
# Processing Record 11 of Set 5 | shymkent
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | poronaysk
# Processing Record 14 of Set 5 | adrar
# Processing Record 15 of Set 5 | namie
# Processing Record 16 of Set 5 | bambous virieux
# Processing Record 17 of Set 5 | saint-georges
# Processing Record 18 of Set 5 | chara
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | srednekolymsk
# Processing Record 21 of Set 5 | mao
# Processing Record 22 of Set 5 | along
# Processing Record 23 of Set 5 | iranshahr
# Processing Record 24 of Set 5 | waingapu
# Processing Record 25 of Set 5 | bar
# Processing Record 26 of Set 5 | benavente
# Processing Record 27 of Set 5 | verkhnevilyuysk
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | tecoanapa
# Processing Record 30 of Set 5 | agva
# City not found. Skipping...
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | ugoofaaru
# Processing Record 33 of Set 5 | erzin
# Processing Record 34 of Set 5 | voh
# Processing Record 35 of Set 5 | metkovic
# Processing Record 36 of Set 5 | baiao
# Processing Record 37 of Set 5 | manakara
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | borba
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | itambe
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | marzuq
# Processing Record 44 of Set 5 | estelle
# Processing Record 45 of Set 5 | kupang
# Processing Record 46 of Set 5 | basoko
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 49 of Set 5 | san rafael
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | pemagatsel
# Processing Record 2 of Set 6 | port elizabeth
# Processing Record 3 of Set 6 | atuona
# Processing Record 4 of Set 6 | nuuk
# Processing Record 5 of Set 6 | medea
# Processing Record 6 of Set 6 | pyaozerskiy
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | uk
# City not found. Skipping...
# Processing Record 11 of Set 6 | natal
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | ewa beach
# Processing Record 14 of Set 6 | cap malheureux
# Processing Record 15 of Set 6 | kisangani
# Processing Record 16 of Set 6 | kitami
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | geraldton
# Processing Record 19 of Set 6 | tessalit
# Processing Record 20 of Set 6 | tonj
# Processing Record 21 of Set 6 | champerico
# Processing Record 22 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 6 | mitzic
# Processing Record 24 of Set 6 | puerto del rosario
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | georgetown
# Processing Record 28 of Set 6 | sivaki
# Processing Record 29 of Set 6 | shakawe
# Processing Record 30 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 6 | high level
# Processing Record 32 of Set 6 | moctezuma
# Processing Record 33 of Set 6 | aberdeen
# Processing Record 34 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | cervo
# Processing Record 36 of Set 6 | port macquarie
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | hambantota
# Processing Record 39 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 40 of Set 6 | kuusamo
# Processing Record 41 of Set 6 | rosetta
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | portland
# Processing Record 44 of Set 6 | bassila
# Processing Record 45 of Set 6 | clyde river
# Processing Record 46 of Set 6 | gat
# Processing Record 47 of Set 6 | helong
# Processing Record 48 of Set 6 | mitsamiouli
# Processing Record 49 of Set 6 | thinadhoo
# Processing Record 50 of Set 6 | jasper
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | mattawa
# Processing Record 3 of Set 7 | xifeng
# Processing Record 4 of Set 7 | kahului
# Processing Record 5 of Set 7 | zuenoula
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | ivanivka
# Processing Record 8 of Set 7 | bacolod
# Processing Record 9 of Set 7 | shimoda
# Processing Record 10 of Set 7 | oro valley
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | trairi
# Processing Record 13 of Set 7 | porto novo
# Processing Record 14 of Set 7 | nakamura
# Processing Record 15 of Set 7 | kathmandu
# Processing Record 16 of Set 7 | tahoua
# Processing Record 17 of Set 7 | nishihara
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | noshiro
# Processing Record 20 of Set 7 | pareora
# Processing Record 21 of Set 7 | phalombe
# Processing Record 22 of Set 7 | baghdad
# Processing Record 23 of Set 7 | buchanan
# Processing Record 24 of Set 7 | buala
# Processing Record 25 of Set 7 | springville
# Processing Record 26 of Set 7 | soyo
# Processing Record 27 of Set 7 | novikovo
# Processing Record 28 of Set 7 | pacifica
# Processing Record 29 of Set 7 | broken hill
# Processing Record 30 of Set 7 | tudela
# Processing Record 31 of Set 7 | galesong
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | dekar
# Processing Record 34 of Set 7 | riyadh
# Processing Record 35 of Set 7 | seoul
# Processing Record 36 of Set 7 | yantzaza
# Processing Record 37 of Set 7 | saint-augustin
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | bilibino
# Processing Record 40 of Set 7 | somerville
# Processing Record 41 of Set 7 | north bend
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | sao jose da coroa grande
# Processing Record 44 of Set 7 | saskylakh
# Processing Record 45 of Set 7 | kirkenaer
# Processing Record 46 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 7 | tateyama
# Processing Record 48 of Set 7 | locri
# Processing Record 49 of Set 7 | casma
# Processing Record 50 of Set 7 | nizhniy kuranakh
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | najran
# Processing Record 3 of Set 8 | teknaf
# Processing Record 4 of Set 8 | anaco
# Processing Record 5 of Set 8 | thiruvananthapuram
# Processing Record 6 of Set 8 | vila franca do campo
# Processing Record 7 of Set 8 | acapulco
# Processing Record 8 of Set 8 | develi
# Processing Record 9 of Set 8 | luwingu
# Processing Record 10 of Set 8 | yinchuan
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | abalak
# Processing Record 13 of Set 8 | lata
# Processing Record 14 of Set 8 | istra
# Processing Record 15 of Set 8 | montepuez
# Processing Record 16 of Set 8 | itamaraca
# Processing Record 17 of Set 8 | leonidovo
# Processing Record 18 of Set 8 | berezanskaya
# Processing Record 19 of Set 8 | turukhansk
# Processing Record 20 of Set 8 | mweka
# Processing Record 21 of Set 8 | santa rosa
# Processing Record 22 of Set 8 | urbana
# Processing Record 23 of Set 8 | tarut
# Processing Record 24 of Set 8 | fort nelson
# Processing Record 25 of Set 8 | kaeo
# Processing Record 26 of Set 8 | bakel
# Processing Record 27 of Set 8 | atambua
# Processing Record 28 of Set 8 | eniwa
# Processing Record 29 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 8 | gushikawa
# Processing Record 31 of Set 8 | samarai
# Processing Record 32 of Set 8 | senhor do bonfim
# Processing Record 33 of Set 8 | husavik
# Processing Record 34 of Set 8 | acarau
# Processing Record 35 of Set 8 | muroto
# Processing Record 36 of Set 8 | kuryk
# Processing Record 37 of Set 8 | bitung
# Processing Record 38 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 8 | quila
# Processing Record 40 of Set 8 | sobolevo
# Processing Record 41 of Set 8 | filadelfia
# Processing Record 42 of Set 8 | alice springs
# Processing Record 43 of Set 8 | lazarev
# Processing Record 44 of Set 8 | dunmore town
# Processing Record 45 of Set 8 | manokwari
# Processing Record 46 of Set 8 | anito
# Processing Record 47 of Set 8 | makung
# City not found. Skipping...
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | usogorsk
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | gisborne
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | qaqortoq
# Processing Record 4 of Set 9 | atherton
# Processing Record 5 of Set 9 | were ilu
# Processing Record 6 of Set 9 | biak
# Processing Record 7 of Set 9 | tarata
# Processing Record 8 of Set 9 | vihti
# Processing Record 9 of Set 9 | sirpur
# Processing Record 10 of Set 9 | deputatskiy
# Processing Record 11 of Set 9 | kavaratti
# Processing Record 12 of Set 9 | mount gambier
# Processing Record 13 of Set 9 | mkuranga
# Processing Record 14 of Set 9 | ouadda
# Processing Record 15 of Set 9 | harper
# Processing Record 16 of Set 9 | marang
# Processing Record 17 of Set 9 | zhigansk
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | talnakh
# Processing Record 20 of Set 9 | uruzgan
# Processing Record 21 of Set 9 | xiongzhou
# Processing Record 22 of Set 9 | christchurch
# Processing Record 23 of Set 9 | pauini
# Processing Record 24 of Set 9 | baiyin
# Processing Record 25 of Set 9 | pevek
# Processing Record 26 of Set 9 | port blair
# Processing Record 27 of Set 9 | dali
# Processing Record 28 of Set 9 | jiutai
# Processing Record 29 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 9 | kunming
# Processing Record 31 of Set 9 | xiaoweizhai
# Processing Record 32 of Set 9 | port arthur
# Processing Record 33 of Set 9 | borovoy
# Processing Record 34 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 9 | jizan
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint anthony
# Processing Record 38 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 9 | canmore
# Processing Record 40 of Set 9 | moree
# Processing Record 41 of Set 9 | vangaindrano
# Processing Record 42 of Set 9 | los amates
# Processing Record 43 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 9 | gustrow
# Processing Record 45 of Set 9 | hasaki
# Processing Record 46 of Set 9 | ponta delgada
# Processing Record 47 of Set 9 | sri aman
# Processing Record 48 of Set 9 | pontianak
# Processing Record 49 of Set 9 | tiarei
# Processing Record 50 of Set 9 | cabo san lucas
# Processing Record 1 of Set 10 | wyndham
# Processing Record 2 of Set 10 | vacaria
# Processing Record 3 of Set 10 | mbandaka
# Processing Record 4 of Set 10 | wharton
# Processing Record 5 of Set 10 | umarkot
# Processing Record 6 of Set 10 | shelburne
# Processing Record 7 of Set 10 | tromso
# Processing Record 8 of Set 10 | caninde de sao francisco
# Processing Record 9 of Set 10 | rundu
# Processing Record 10 of Set 10 | dolzhanskaya
# Processing Record 11 of Set 10 | arcata
# Processing Record 12 of Set 10 | brusque
# Processing Record 13 of Set 10 | ketchikan
# Processing Record 14 of Set 10 | rudbar
# Processing Record 15 of Set 10 | praia da vitoria
# Processing Record 16 of Set 10 | san patricio
# Processing Record 17 of Set 10 | fukue
# Processing Record 18 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 10 | san juan
# Processing Record 20 of Set 10 | el alto
# Processing Record 21 of Set 10 | abu samrah
# Processing Record 22 of Set 10 | ipixuna
# Processing Record 23 of Set 10 | araouane
# Processing Record 24 of Set 10 | dumas
# Processing Record 25 of Set 10 | prince rupert
# Processing Record 26 of Set 10 | mutuipe
# Processing Record 27 of Set 10 | wageningen
# Processing Record 28 of Set 10 | meulaboh
# Processing Record 29 of Set 10 | guerrero negro
# Processing Record 30 of Set 10 | asyut
# Processing Record 31 of Set 10 | saint-pierre
# Processing Record 32 of Set 10 | deniliquin
# Processing Record 33 of Set 10 | conceicao da barra
# Processing Record 34 of Set 10 | grand forks
# Processing Record 35 of Set 10 | the valley
# Processing Record 36 of Set 10 | coquimbo
# Processing Record 37 of Set 10 | moron
# Processing Record 38 of Set 10 | graham
# Processing Record 39 of Set 10 | hami
# Processing Record 40 of Set 10 | tyup
# Processing Record 41 of Set 10 | kharp
# Processing Record 42 of Set 10 | sovetskaya
# Processing Record 43 of Set 10 | kruisfontein
# Processing Record 44 of Set 10 | palmer
# Processing Record 45 of Set 10 | canavieiras
# Processing Record 46 of Set 10 | hovd
# Processing Record 47 of Set 10 | port hueneme
# Processing Record 48 of Set 10 | hot springs
# Processing Record 49 of Set 10 | berezovka
# Processing Record 50 of Set 10 | kiama
# Processing Record 1 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 11 | nicoya
# Processing Record 3 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | starnberg
# Processing Record 5 of Set 11 | margate
# Processing Record 6 of Set 11 | mugumu
# Processing Record 7 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 11 | kampot
# Processing Record 9 of Set 11 | kirakira
# Processing Record 10 of Set 11 | goderich
# Processing Record 11 of Set 11 | belaya gora
# Processing Record 12 of Set 11 | walvis bay
# Processing Record 13 of Set 11 | luganville
# Processing Record 14 of Set 11 | leo
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | ossora
# Processing Record 17 of Set 11 | gimli
# Processing Record 18 of Set 11 | clinton
# Processing Record 19 of Set 11 | osinki
# Processing Record 20 of Set 11 | hervey bay
# Processing Record 21 of Set 11 | bria
# Processing Record 22 of Set 11 | lukovetskiy
# Processing Record 23 of Set 11 | yaan
# Processing Record 24 of Set 11 | cam ranh
# Processing Record 25 of Set 11 | puerto escondido
# Processing Record 26 of Set 11 | narasannapeta
# Processing Record 27 of Set 11 | culebra
# Processing Record 28 of Set 11 | bansi
# Processing Record 29 of Set 11 | aykhal
# Processing Record 30 of Set 11 | doctor juan leon mallorquin
# Processing Record 31 of Set 11 | yichun
# Processing Record 32 of Set 11 | jhalrapatan
# Processing Record 33 of Set 11 | inongo
# Processing Record 34 of Set 11 | dingle
# Processing Record 35 of Set 11 | nabire
# Processing Record 36 of Set 11 | nguruka
# Processing Record 37 of Set 11 | jaisalmer
# Processing Record 38 of Set 11 | kostomuksha
# Processing Record 39 of Set 11 | langsa
# Processing Record 40 of Set 11 | tahta
# Processing Record 41 of Set 11 | tweed
# Processing Record 42 of Set 11 | maldonado
# Processing Record 43 of Set 11 | parabel
# Processing Record 44 of Set 11 | abha
# Processing Record 45 of Set 11 | caernarfon
# Processing Record 46 of Set 11 | henderson
# Processing Record 47 of Set 11 | antsohihy
# Processing Record 48 of Set 11 | oslavany
# Processing Record 49 of Set 11 | harindanga
# Processing Record 50 of Set 11 | marrakesh
# Processing Record 1 of Set 12 | kungurtug
# Processing Record 2 of Set 12 | beroroha
# Processing Record 3 of Set 12 | jieshi
# Processing Record 4 of Set 12 | ostrovnoy
# Processing Record 5 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 6 of Set 12 | dera ismail khan
# Processing Record 7 of Set 12 | chudniv
# Processing Record 8 of Set 12 | alta floresta
# Processing Record 9 of Set 12 | darhan
# Processing Record 10 of Set 12 | grenada
# Processing Record 11 of Set 12 | butajira
# Processing Record 12 of Set 12 | nadym
# Processing Record 13 of Set 12 | carnduff
# Processing Record 14 of Set 12 | faya
# Processing Record 15 of Set 12 | leh
# Processing Record 16 of Set 12 | carutapera
# Processing Record 17 of Set 12 | lagoa
# Processing Record 18 of Set 12 | anahuac
# Processing Record 19 of Set 12 | xingcheng
# Processing Record 20 of Set 12 | todos santos
# Processing Record 21 of Set 12 | ciudad bolivar
# Processing Record 22 of Set 12 | gopalur
# Processing Record 23 of Set 12 | nuevo progreso
# Processing Record 24 of Set 12 | rocha
# Processing Record 25 of Set 12 | krasnoselkup
# Processing Record 26 of Set 12 | hobyo
# Processing Record 27 of Set 12 | maumere
# Processing Record 28 of Set 12 | jalu
# Processing Record 29 of Set 12 | cap-aux-meules
# Processing Record 30 of Set 12 | turayf
# Processing Record 31 of Set 12 | weihai
# Processing Record 32 of Set 12 | baruun-urt
# Processing Record 33 of Set 12 | pandan
# Processing Record 34 of Set 12 | evensk
# Processing Record 35 of Set 12 | havelock
# Processing Record 36 of Set 12 | fortuna foothills
# Processing Record 37 of Set 12 | la peca
# Processing Record 38 of Set 12 | hamilton
# Processing Record 39 of Set 12 | yuli
# Processing Record 40 of Set 12 | tuy hoa
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | upata
# Processing Record 43 of Set 12 | moose factory
# Processing Record 44 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 12 | batticaloa
# Processing Record 46 of Set 12 | kamyshlov
# Processing Record 47 of Set 12 | cloquet
# Processing Record 48 of Set 12 | miri
# Processing Record 49 of Set 12 | acari
# Processing Record 50 of Set 12 | sayyan
# Processing Record 1 of Set 13 | egvekinot
# Processing Record 2 of Set 13 | juegang
# Processing Record 3 of Set 13 | terney
# Processing Record 4 of Set 13 | mvuma
# Processing Record 5 of Set 13 | noyabrsk
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | labuhan
# Processing Record 8 of Set 13 | rawson
# Processing Record 9 of Set 13 | orlik
# Processing Record 10 of Set 13 | mecca
# Processing Record 11 of Set 13 | dhidhdhoo
# Processing Record 12 of Set 13 | mitry-mory
# Processing Record 13 of Set 13 | te anau
# Processing Record 14 of Set 13 | atyrau
# Processing Record 15 of Set 13 | kuvshinovo
# Processing Record 16 of Set 13 | celendin
# Processing Record 17 of Set 13 | xining
# Processing Record 18 of Set 13 | duldurga
# Processing Record 19 of Set 13 | kasrawad
# Processing Record 20 of Set 13 | college
# Processing Record 21 of Set 13 | sapozhok
# Processing Record 22 of Set 13 | oulu
# Processing Record 23 of Set 13 | svetogorsk
# Processing Record 24 of Set 13 | waw
# Processing Record 25 of Set 13 | barrancabermeja
# Processing Record 26 of Set 13 | la rioja
# Processing Record 27 of Set 13 | port-cartier
# Processing Record 28 of Set 13 | verkhoyansk
# Processing Record 29 of Set 13 | la macarena
# Processing Record 30 of Set 13 | fayaoue
# Processing Record 31 of Set 13 | tairua
# Processing Record 32 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 13 | nyurba
# Processing Record 34 of Set 13 | nalut
# Processing Record 35 of Set 13 | biloela
# Processing Record 36 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 13 | tvoroyri
# Processing Record 38 of Set 13 | kathu
# Processing Record 39 of Set 13 | placido de castro
# Processing Record 40 of Set 13 | verkhnyaya inta
# Processing Record 41 of Set 13 | santa cruz
# Processing Record 42 of Set 13 | leshukonskoye
# Processing Record 43 of Set 13 | waslala
# Processing Record 44 of Set 13 | dafeng
# Processing Record 45 of Set 13 | ixtapa
# Processing Record 46 of Set 13 | herat
# Processing Record 47 of Set 13 | udalguri
# Processing Record 48 of Set 13 | vila
# Processing Record 49 of Set 13 | ampanihy
# Processing Record 50 of Set 13 | ati
# Processing Record 1 of Set 14 | chemal
# Processing Record 2 of Set 14 | sal rei
# Processing Record 3 of Set 14 | terme
# Processing Record 4 of Set 14 | gambela
# Processing Record 5 of Set 14 | arya
# Processing Record 6 of Set 14 | iberia
# Processing Record 7 of Set 14 | mikhaylovsk
# Processing Record 8 of Set 14 | snasa
# Processing Record 9 of Set 14 | lishui
# Processing Record 10 of Set 14 | porbandar
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | alexandria
# Processing Record 13 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 14 | waipawa
# Processing Record 15 of Set 14 | grand gaube
# Processing Record 16 of Set 14 | shirokiy
# Processing Record 17 of Set 14 | krasnovishersk
# Processing Record 18 of Set 14 | marienburg
# Processing Record 19 of Set 14 | buraydah
# Processing Record 20 of Set 14 | ales
# Processing Record 21 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 22 of Set 14 | cravo norte
# Processing Record 23 of Set 14 | ballina
# Processing Record 24 of Set 14 | chapleau
# Processing Record 25 of Set 14 | vieux-habitants
# Processing Record 26 of Set 14 | ulefoss
# Processing Record 27 of Set 14 | belyy yar
# Processing Record 28 of Set 14 | arkhara
# Processing Record 29 of Set 14 | kodaikanal
# Processing Record 30 of Set 14 | roswell
# Processing Record 31 of Set 14 | ocampo
# Processing Record 32 of Set 14 | aketi
# Processing Record 33 of Set 14 | saint-fabien
# City not found. Skipping...
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | tunduma
# Processing Record 36 of Set 14 | anzio
# Processing Record 37 of Set 14 | saint-francois
# Processing Record 38 of Set 14 | anadyr
# Processing Record 39 of Set 14 | cowra
# Processing Record 40 of Set 14 | fortaleza
# Processing Record 41 of Set 14 | takoradi
# Processing Record 42 of Set 14 | karpathos
# Processing Record 43 of Set 14 | gamba
# Processing Record 44 of Set 14 | sol-iletsk
# Processing Record 45 of Set 14 | bronnoysund
# Processing Record 46 of Set 14 | chake chake
# Processing Record 47 of Set 14 | ndjole
# Processing Record 48 of Set 14 | steinbach
# Processing Record 49 of Set 14 | velikodvorskiy
# Processing Record 50 of Set 14 | florencia
# Processing Record 1 of Set 15 | saint george
# Processing Record 2 of Set 15 | goedereede
# Processing Record 3 of Set 15 | uusikaupunki
# Processing Record 4 of Set 15 | udankudi
# Processing Record 5 of Set 15 | ahipara
# Processing Record 6 of Set 15 | nikolayevka
# Processing Record 7 of Set 15 | isakly
# Processing Record 8 of Set 15 | mbinga
# Processing Record 9 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 15 | eyl
# Processing Record 11 of Set 15 | sirfa
# City not found. Skipping...
# Processing Record 12 of Set 15 | andarab
# City not found. Skipping...
# Processing Record 13 of Set 15 | mariinskiy posad
# Processing Record 14 of Set 15 | tsaratanana
# Processing Record 15 of Set 15 | toamasina
# Processing Record 16 of Set 15 | alyangula
# Processing Record 17 of Set 15 | sorong
# Processing Record 18 of Set 15 | bereda
# Processing Record 19 of Set 15 | tres rios
# Processing Record 20 of Set 15 | markova
# Processing Record 21 of Set 15 | koungou
# Processing Record 22 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 15 | inzer
# Processing Record 24 of Set 15 | hirara
# Processing Record 25 of Set 15 | new richmond
# Processing Record 26 of Set 15 | zarya
# Processing Record 27 of Set 15 | trinidad
# Processing Record 28 of Set 15 | la romana
# Processing Record 29 of Set 15 | zhanakorgan
# Processing Record 30 of Set 15 | santa rosalia
# Processing Record 31 of Set 15 | urengoy
# Processing Record 32 of Set 15 | belozerskoye
# Processing Record 33 of Set 15 | iracoubo
# Processing Record 34 of Set 15 | bantou
# Processing Record 35 of Set 15 | shirokaya rechka
# Processing Record 36 of Set 15 | los llanos de aridane
# Processing Record 37 of Set 15 | beira
# Processing Record 38 of Set 15 | ust-kishert
# Processing Record 39 of Set 15 | sur
# Processing Record 40 of Set 15 | humaita
# Processing Record 41 of Set 15 | tigil
# Processing Record 42 of Set 15 | sangin
# Processing Record 43 of Set 15 | kudahuvadhoo
# Processing Record 44 of Set 15 | miles city
# Processing Record 45 of Set 15 | benghazi
# Processing Record 46 of Set 15 | cururupu
# Processing Record 47 of Set 15 | kaduna
# Processing Record 48 of Set 15 | atwater
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | zaranj
# Processing Record 1 of Set 16 | tupik
# Processing Record 2 of Set 16 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 16 | kalispell
# Processing Record 4 of Set 16 | san jose
# Processing Record 5 of Set 16 | high prairie
# Processing Record 6 of Set 16 | prachin buri
# Processing Record 7 of Set 16 | laguna
# Processing Record 8 of Set 16 | muzaffarpur
# Processing Record 9 of Set 16 | landau
# Processing Record 10 of Set 16 | mendi
# Processing Record 11 of Set 16 | oltu
# Processing Record 12 of Set 16 | sola
# Processing Record 13 of Set 16 | wuchi
# Processing Record 14 of Set 16 | fenoarivo
# Processing Record 15 of Set 16 | garowe
# Processing Record 16 of Set 16 | plouzane
# Processing Record 17 of Set 16 | guozhen
# Processing Record 18 of Set 16 | tangshan
# Processing Record 19 of Set 16 | debre zeyit
# Processing Record 20 of Set 16 | burnie
# Processing Record 21 of Set 16 | danjiangkou
# Processing Record 22 of Set 16 | juybar
# Processing Record 23 of Set 16 | dalbandin
# Processing Record 24 of Set 16 | tvedestrand
# Processing Record 25 of Set 16 | ambilobe
# Processing Record 26 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 16 | bilma
# Processing Record 28 of Set 16 | ranot
# Processing Record 29 of Set 16 | kismayo
# Processing Record 30 of Set 16 | morgan city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 732

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus -34.4187   19.2345     71.80        79          96
# 1       Tucurui  -3.7661  -49.6725     72.21        98         100
# 2         Alofi -19.0595 -169.9187     78.69        83          52
# 3        Avarua -21.2078 -159.7750     80.65        69          75
# 4  Punta Arenas -53.1500  -70.9167     51.91        71           0
# 5       Isangel -19.5500  169.2667     86.11        70          88
# 6       Rikitea -23.1203 -134.9692     77.95        72          10
# 7     Busselton -33.6500  115.3333     71.13        47           1
# 8     Tuatapere -46.1333  167.6833     75.29        44          11
# 9  Richards Bay -28.7830   32.0377     70.97        95           4
#
#    Wind Speed Country Current Description
# 0       18.01      ZA     overcast clouds
# 1        2.64      BR     overcast clouds
# 2        5.75      NU       broken clouds
# 3        6.91      CK       broken clouds
# 4       25.32      CL          light rain
# 5        4.61      VU     overcast clouds
# 6       12.10      PF           clear sky
# 7       16.60      AU           clear sky
# 8        2.89      NZ          few clouds
# 9        5.17      ZA           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     71.80        79          96
# 1       Tucurui      BR  -3.7661  -49.6725     72.21        98         100
# 2         Alofi      NU -19.0595 -169.9187     78.69        83          52
# 3        Avarua      CK -21.2078 -159.7750     80.65        69          75
# 4  Punta Arenas      CL -53.1500  -70.9167     51.91        71           0
# 5       Isangel      VU -19.5500  169.2667     86.11        70          88
# 6       Rikitea      PF -23.1203 -134.9692     77.95        72          10
# 7     Busselton      AU -33.6500  115.3333     71.13        47           1
# 8     Tuatapere      NZ -46.1333  167.6833     75.29        44          11
# 9  Richards Bay      ZA -28.7830   32.0377     70.97        95           4
#
#    Wind Speed Current Description
# 0       18.01     overcast clouds
# 1        2.64     overcast clouds
# 2        5.75       broken clouds
# 3        6.91       broken clouds
# 4       25.32          light rain
# 5        4.61     overcast clouds
# 6       12.10           clear sky
# 7       16.60           clear sky
# 8        2.89          few clouds
# 9        5.17           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
